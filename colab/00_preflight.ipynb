# %% [markdown]
# # NovaBridge — Preflight (Colab)
#
# Run this first. It clones the workshop repo, installs pinned dependencies, and runs the environment self-check.

# %%
# AUTHOR TODO: replace REPO_URL with the real GitHub URL before the workshop
REPO_URL = "https://github.com/REPLACE-ME/nova-agent-infra.git"
# !git clone $REPO_URL repo
# %cd repo
# !pip install -q -r requirements.txt

# %%
# !python preflight.py
