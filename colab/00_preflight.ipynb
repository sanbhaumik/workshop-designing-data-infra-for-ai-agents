# %% [markdown]
# # NovaBridge — Setup & Preflight (Colab)
#
# Run this first. It clones the repo, installs Postgres + Ollama + the model + Python deps, and runs the environment self-check. The setup cell takes a few minutes the first time.
#
# If your Colab session disconnects, just re-run these cells — setup is idempotent.

# %%
# !git clone https://github.com/sanbhaumik/workshop-designing-data-infra-for-ai-agents.git repo
# %cd repo

# %%
# !bash setup.sh

# %%
import os
os.environ['NOVA_LLM'] = 'ollama'
os.environ['OLLAMA_MODEL'] = 'llama3.2:1b'
os.environ['DATABASE_URL'] = 'postgresql://postgres@localhost:5432/nova'
print('environment configured')

# %%
# !python preflight.py
